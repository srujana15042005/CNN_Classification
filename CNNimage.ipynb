# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense , Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# C:\Users\sruja\AppData\Roaming\Python\Python312\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
X_train = np.loadtxt('input.csv', delimiter=',')
Y_train = np.loadtxt('labels.csv', delimiter=',')

X_test = np.loadtxt('input_test.csv', delimiter=',')
Y_test = np.loadtxt('labels_test.csv', delimiter=',')

# %%
X_train = X_train.reshape(len(X_train),100,100,3)
Y_train = Y_train.reshape(len(Y_train),1)

X_test = X_test.reshape(len(X_test),100,100,3)
Y_test = Y_test.reshape(len(Y_test),1)

X_train = X_train / 255.0
X_test = X_test / 255.0

#data augmentation to improve training
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
print("shape of X_train:", X_train.shape)
print("shape of Y_train:", Y_train.shape)
print("shape of X_test:", X_test.shape) 
print("shape of Y_test:", Y_test.shape)
# Out:
# shape of X_train: (2000, 100, 100, 3)
# shape of Y_train: (2000, 1)
# shape of X_test: (400, 100, 100, 3)
# shape of Y_test: (400, 1)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %%
model=Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(100,100,3)),
    MaxPooling2D((2,2)),

    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(64,activation='relu'),
    Dense(1,activation='sigmoid')
])
# Out:
# C:\Users\sruja\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation= 'relu', input_shape = (100,100,3))) # 32,64 is the filter
model.add(MaxPooling2D((2,2)))# converting 2d data to 1d data
model.add(Dropout(0.25)) # to remove particular data from the dataset

model.add(Conv2D(64, (3,3), activation= 'relu'))#(3,3) is the size of the filter( hidden layers)
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(datagen.flow(X_train, Y_train, batch_size=32),
          epochs=30,
          validation_data=(X_test, Y_test),
          verbose=1)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.5025 - loss: 0.7122 - val_accuracy: 0.4950 - val_loss: 0.6931
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5145 - loss: 0.6935 - val_accuracy: 0.5025 - val_loss: 0.6924
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.4950 - loss: 0.6939 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.5285 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6924
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.5380 - loss: 0.6915 - val_accuracy: 0.5150 - val_loss: 0.6926
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.5055 - loss: 0.6933 - val_accuracy: 0.5275 - val_loss: 0.6930
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5110 - loss: 0.6916 - val_accuracy: 0.5675 - val_loss: 0.6889
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.5565 - loss: 0.6856 - val_accuracy: 0.5650 - val_loss: 0.6826
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.5580 - loss: 0.6846 - val_accuracy: 0.6000 - val_loss: 0.6750
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5525 - loss: 0.6843 - val_accuracy: 0.5825 - val_loss: 0.6785
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5485 - loss: 0.6813 - val_accuracy: 0.6250 - val_loss: 0.6703
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5755 - loss: 0.6797 - val_accuracy: 0.6600 - val_loss: 0.6718
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.5705 - loss: 0.6775 - val_accuracy: 0.5900 - val_loss: 0.6739
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5795 - loss: 0.6814 - val_accuracy: 0.6225 - val_loss: 0.6615
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.5840 - loss: 0.6721 - val_accuracy: 0.5575 - val_loss: 0.6791
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.5775 - loss: 0.6725 - val_accuracy: 0.6350 - val_loss: 0.6798
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.5760 - loss: 0.6762 - val_accuracy: 0.6275 - val_loss: 0.6548
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.5720 - loss: 0.6681 - val_accuracy: 0.5475 - val_loss: 0.6787
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.5960 - loss: 0.6562 - val_accuracy: 0.6175 - val_loss: 0.6633
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.6065 - loss: 0.6537 - val_accuracy: 0.6450 - val_loss: 0.6207
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.6130 - loss: 0.6500 - val_accuracy: 0.6525 - val_loss: 0.6300
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.6135 - loss: 0.6450 - val_accuracy: 0.6525 - val_loss: 0.6217
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.6320 - loss: 0.6423 - val_accuracy: 0.6825 - val_loss: 0.6319
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.6460 - loss: 0.6331 - val_accuracy: 0.6575 - val_loss: 0.6227
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.6420 - loss: 0.6351 - val_accuracy: 0.6800 - val_loss: 0.6182
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.6435 - loss: 0.6224 - val_accuracy: 0.6975 - val_loss: 0.5983
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.6415 - loss: 0.6216 - val_accuracy: 0.5675 - val_loss: 0.7065
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.6615 - loss: 0.6154 - val_accuracy: 0.6950 - val_loss: 0.5894
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.6595 - loss: 0.6155 - val_accuracy: 0.7400 - val_loss: 0.5810
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - accuracy: 0.6640 - loss: 0.6122 - val_accuracy: 0.7050 - val_loss: 0.5839

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7050 - loss: 0.5839
# [0.5838856101036072, 0.7049999833106995]

# %%
idx2= random.randint(0, len(Y_test))
plt.imshow(X_test[idx2, :])
plt.show()

y_pred = model.predict(X_test[idx2, :].reshape(1,100,100,3))
y_pred = y_pred > 0.5

if(y_pred == 0):
    pred = "dog"

else: 
    pred = 'cat'

print("The model prediction is", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# The model prediction is dog

# %%
model.save('model.h5')
print('our model is saved')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# our model is saved
